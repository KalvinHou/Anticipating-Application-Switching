# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt

# %% [markdown]
# # c0fe

# %%
# %run HCI_SimpleModel_(c0fe).ipynb
# Out:
# INPUT DATA:
# 162
# ...

# %%
feature_valid_app_c0fe=feature_valid_app
feature_valid_duration_c0fe=feature_valid_duration
feature_valid_switchingTimeDate_c0fe=feature_valid_switchingTimeDate
feature_valid_deviceStatus3_c0fe=feature_valid_deviceStatus3
feature_valid_touchTimes3_c0fe=feature_valid_touchTimes3
feature_valid_app_category_c0fe=feature_valid_app_category
feature_valid_app_frequency_c0fe=feature_valid_app_frequency
features_mean_video_c0fe=features_mean_video
features_var_video_c0fe=features_var_video
features_std_video_c0fe=features_std_video
label_valid_category_c0fe=label_valid_category
label_valid_app_c0fe=label_valid_app

# %%
print(feature_valid_app_c0fe.shape)
print(feature_valid_duration_c0fe.shape)
print(feature_valid_switchingTimeDate_c0fe.shape)
print(feature_valid_deviceStatus3_c0fe.shape)
print(feature_valid_touchTimes3_c0fe.shape)
print(feature_valid_app_category_c0fe.shape)
print(feature_valid_app_frequency_c0fe.shape)
print(features_mean_video_c0fe.shape)
print(features_var_video_c0fe.shape)
print(features_std_video_c0fe.shape)
print(label_valid_category_c0fe.shape)
print(label_valid_app_c0fe.shape)
# Out:
# (101, 1)
# (101, 1)
# (101, 1)
# (101, 1)
# (101, 1)
# (101, 1)
# (101, 1)
# (101, 8)
# (101, 8)
# (101, 8)
# (101,)
# (101,)

# %%
allFeatures_c0fe = np.concatenate([feature_valid_app_c0fe ,
                              feature_valid_duration_c0fe ,
                              feature_valid_switchingTimeDate_c0fe ,
                              feature_valid_deviceStatus3_c0fe ,
                              feature_valid_touchTimes3_c0fe ,
                              feature_valid_app_category_c0fe , 
                              feature_valid_app_frequency_c0fe , 
                              features_mean_video_c0fe , 
                              features_var_video_c0fe ,
                              features_std_video_c0fe ],
                              axis=1)
print(allFeatures_c0fe.shape)
# Out:
# (101, 31)

# %% [markdown]
# # 7711

# %%
# %run HCI_SimpleModel_(7711).ipynb
# Out:
# INPUT DATA:
# 128
# ...

# %%
feature_valid_app_7711=feature_valid_app
feature_valid_duration_7711=feature_valid_duration
feature_valid_switchingTimeDate_7711=feature_valid_switchingTimeDate
feature_valid_deviceStatus3_7711=feature_valid_deviceStatus3
feature_valid_touchTimes3_7711=feature_valid_touchTimes3
feature_valid_app_category_7711=feature_valid_app_category
feature_valid_app_frequency_7711=feature_valid_app_frequency
features_mean_video_7711=features_mean_video
features_var_video_7711=features_var_video
features_std_video_7711=features_std_video
label_valid_category_7711=label_valid_category
label_valid_app_7711=label_valid_app

# %%
print(feature_valid_app_7711.shape)
print(feature_valid_duration_7711.shape)
print(feature_valid_switchingTimeDate_7711.shape)
print(feature_valid_deviceStatus3_7711.shape)
print(feature_valid_touchTimes3_7711.shape)
print(feature_valid_app_category_7711.shape)
print(feature_valid_app_frequency_7711.shape)
print(features_mean_video_7711.shape)
print(features_var_video_7711.shape)
print(features_std_video_7711.shape)
print(label_valid_category_7711.shape)
print(label_valid_app_7711.shape)
# Out:
# (110, 1)
# (110, 1)
# (110, 1)
# (110, 1)
# (110, 1)
# (110, 1)
# (110, 1)
# (110, 8)
# (110, 8)
# (110, 8)
# (110,)
# (110,)

# %%
allFeatures_7711 = np.concatenate([feature_valid_app_7711,
                              feature_valid_duration_7711,
                              feature_valid_switchingTimeDate_7711,
                              feature_valid_deviceStatus3_7711,
                              feature_valid_touchTimes3_7711,
                              feature_valid_app_category_7711, 
                              feature_valid_app_frequency_7711, 
                              features_mean_video_7711, 
                              features_var_video_7711,
                              features_std_video_7711],
                              axis=1)
print(allFeatures_7711.shape)
# Out:
# (110, 31)

# %% [markdown]
# # 9815

# %%
# %run HCI_SimpleModel_(9815).ipynb
# Out:
# INPUT DATA:
# 665
# ...

# %%
feature_valid_app_9815=feature_valid_app
feature_valid_duration_9815=feature_valid_duration
feature_valid_switchingTimeDate_9815=feature_valid_switchingTimeDate
feature_valid_deviceStatus3_9815=feature_valid_deviceStatus3
feature_valid_touchTimes3_9815=feature_valid_touchTimes3
feature_valid_app_category_9815=feature_valid_app_category
feature_valid_app_frequency_9815=feature_valid_app_frequency
features_mean_video_9815=features_mean_video
features_var_video_9815=features_var_video
features_std_video_9815=features_std_video
label_valid_category_9815=label_valid_category
label_valid_app_9815=label_valid_app

# %%
print(feature_valid_app_9815.shape)
print(feature_valid_duration_9815.shape)
print(feature_valid_switchingTimeDate_9815.shape)
print(feature_valid_deviceStatus3_9815.shape)
print(feature_valid_touchTimes3_9815.shape)
print(feature_valid_app_category_9815.shape)
print(feature_valid_app_frequency_9815.shape)
print(features_mean_video_9815.shape)
print(features_var_video_9815.shape)
print(features_std_video_9815.shape)
print(label_valid_category_9815.shape)
print(label_valid_app_9815.shape)
# Out:
# (286, 1)
# (286, 1)
# (286, 1)
# (286, 1)
# (286, 1)
# (286, 1)
# (286, 1)
# (286, 8)
# (286, 8)
# (286, 8)
# (286,)
# (286,)

# %%
allFeatures_9815 = np.concatenate([feature_valid_app_9815,
                              feature_valid_duration_9815,
                              feature_valid_switchingTimeDate_9815,
                              feature_valid_deviceStatus3_9815,
                              feature_valid_touchTimes3_9815,
                              feature_valid_app_category_9815, 
                              feature_valid_app_frequency_9815, 
                              features_mean_video_9815, 
                              features_var_video_9815,
                              features_std_video_9815],
                              axis=1)
print(allFeatures_9815.shape)
# Out:
# (286, 31)

# %% [markdown]
# # 681a

# %%
# %run HCI_SimpleModel_(681a).ipynb
# Out:
# INPUT DATA:
# 1394
# ...

# %%
feature_valid_app_681a=feature_valid_app
feature_valid_duration_681a=feature_valid_duration
feature_valid_switchingTimeDate_681a=feature_valid_switchingTimeDate
feature_valid_deviceStatus3_681a=feature_valid_deviceStatus3
feature_valid_touchTimes3_681a=feature_valid_touchTimes3
feature_valid_app_category_681a=feature_valid_app_category
feature_valid_app_frequency_681a=feature_valid_app_frequency
features_mean_video_681a=features_mean_video
features_var_video_681a=features_var_video
features_std_video_681a=features_std_video
label_valid_category_681a=label_valid_category
label_valid_app_681a=label_valid_app

# %%
print(feature_valid_app_681a.shape)
print(feature_valid_duration_681a.shape)
print(feature_valid_switchingTimeDate_681a.shape)
print(feature_valid_deviceStatus3_681a.shape)
print(feature_valid_touchTimes3_681a.shape)
print(feature_valid_app_category_681a.shape)
print(feature_valid_app_frequency_681a.shape)
print(features_mean_video_681a.shape)
print(features_var_video_681a.shape)
print(features_std_video_681a.shape)
print(label_valid_category_681a.shape)
print(label_valid_app_681a.shape)
# Out:
# (248, 1)
# (248, 1)
# (248, 1)
# (248, 1)
# (248, 1)
# (248, 1)
# (248, 1)
# (248, 8)
# (248, 8)
# (248, 8)
# (248,)
# (248,)

# %%
allFeatures_681a = np.concatenate([feature_valid_app_681a,
                              feature_valid_duration_681a,
                              feature_valid_switchingTimeDate_681a,
                              feature_valid_deviceStatus3_681a,
                              feature_valid_touchTimes3_681a,
                              feature_valid_app_category_681a, 
                              feature_valid_app_frequency_681a, 
                              features_mean_video_681a, 
                              features_var_video_681a,
                              features_std_video_681a],
                        axis=1)
print(allFeatures_681a.shape)
# Out:
# (248, 31)

# %% [markdown]
# # 3418

# %%
# %run HCI_SimpleModel_(3418).ipynb
# Out:
# INPUT DATA:
# 470
# ...

# %%
feature_valid_app_3418=feature_valid_app
feature_valid_duration_3418=feature_valid_duration
feature_valid_switchingTimeDate_3418=feature_valid_switchingTimeDate
feature_valid_deviceStatus3_3418=feature_valid_deviceStatus3
feature_valid_touchTimes3_3418=feature_valid_touchTimes3
feature_valid_app_category_3418=feature_valid_app_category
feature_valid_app_frequency_3418=feature_valid_app_frequency
features_mean_video_3418=features_mean_video
features_var_video_3418=features_var_video
features_std_video_3418=features_std_video
label_valid_category_3418=label_valid_category
label_valid_app_3418=label_valid_app

# %%
print(feature_valid_app_3418.shape)
print(feature_valid_duration_3418.shape)
print(feature_valid_switchingTimeDate_3418.shape)
print(feature_valid_deviceStatus3_3418.shape)
print(feature_valid_touchTimes3_3418.shape)
print(feature_valid_app_category_3418.shape)
print(feature_valid_app_frequency_3418.shape)
print(features_mean_video_3418.shape)
print(features_var_video_3418.shape)
print(features_std_video_3418.shape)
print(label_valid_category_3418.shape)
print(label_valid_app_3418.shape)
# Out:
# (388, 1)
# (388, 1)
# (388, 1)
# (388, 1)
# (388, 1)
# (388, 1)
# (388, 1)
# (388, 8)
# (388, 8)
# (388, 8)
# (388,)
# (388,)

# %%
allFeatures_3418 = np.concatenate([feature_valid_app_3418,
                              feature_valid_duration_3418,
                              feature_valid_switchingTimeDate_3418,
                              feature_valid_deviceStatus3_3418,
                              feature_valid_touchTimes3_3418,
                              feature_valid_app_category_3418, 
                              feature_valid_app_frequency_3418, 
                              features_mean_video_3418, 
                              features_var_video_3418,
                              features_std_video_3418],
                        axis=1)
print(allFeatures_3418.shape)
# Out:
# (388, 31)

# %% [markdown]
# # All Datas from 5 participants

# %% [markdown]
# ## App

# %%
general_app = np.concatenate([feature_valid_app_681a,
                              feature_valid_app_7711,
                              feature_valid_app_c0fe,
                              feature_valid_app_9815,
                              feature_valid_app_3418
                             ],
                        axis=0)
print(general_app.shape)
# Out:
# (1133, 1)

# %% [markdown]
# ## Labels

# %%
general_label = np.concatenate([label_valid_app_681a,
                              label_valid_app_7711,
                              label_valid_app_c0fe,
                              label_valid_app_9815,
                              label_valid_app_3418
                             ],
                        axis=0)
print(general_app.shape)
# Out:
# (1133, 1)

# %% [markdown]
# ## All Features

# %%
general_allFeatures = np.concatenate([allFeatures_681a,
                              allFeatures_7711,
                              allFeatures_c0fe,
                              allFeatures_9815,
                              allFeatures_3418
                             ],
                        axis=0)
print(general_allFeatures.shape)
# Out:
# (1133, 31)

# %% [markdown]
# # Functions

# %%
def predict_top_k(X_test, y_test, model, k=3):

    probs = model.predict_proba(X_test)
    labels = model.classes_
    result = 0

    for i in range(probs.shape[0]):
        a = probs[i]
        index = heapq.nlargest(k, range(probs.shape[1]), a.take)
        for element in index:
            if labels[element] == y_test[i]:
                result+=1
    
    return result/y_test.shape[0]

def kNN_training (feature, label):
    valid_X = scaler.fit_transform(feature)
    valid_y = label
    X_train, X_test, y_train, y_test = train_test_split(valid_X, valid_y, random_state=0)
    model = KNeighborsClassifier(n_neighbors=7, weights='uniform').fit(X_train,y_train)
    accuracy = model.score(X_test, y_test)
    top_accuracy4 = predict_top_k(X_test, y_test, model, k=4)
    top_accuracy8 = predict_top_k(X_test, y_test, model, k=8)
    return accuracy, top_accuracy4, top_accuracy8

def rf_training (feature, label):
    valid_X = scaler.fit_transform(feature)
    valid_y = label
    X_train, X_test, y_train, y_test = train_test_split(valid_X, valid_y, random_state=0)
    model = RandomForestClassifier(n_estimators=50).fit(X_train,y_train)
    accuracy = model.score(X_test, y_test)
    top_accuracy4 = predict_top_k(X_test, y_test, model, k=4)
    top_accuracy8 = predict_top_k(X_test, y_test, model, k=8)
    return accuracy, top_accuracy4, top_accuracy8

def Ada_training (feature, label):
    valid_X = scaler.fit_transform(feature)
    valid_y = label
    X_train, X_test, y_train, y_test = train_test_split(valid_X, valid_y, random_state=0)
    model = AdaBoostClassifier(n_estimators=100, random_state=0).fit(X_train,y_train)
    accuracy = model.score(X_test, y_test)
    top_accuracy4 = predict_top_k(X_test, y_test, model, k=4)
    top_accuracy8 = predict_top_k(X_test, y_test, model, k=8)
    return accuracy, top_accuracy4, top_accuracy8

def dummy_training(feature, label):
    dummy = DummyClassifier(strategy="most_frequent")
    dummy = dummy.fit(feature, label)
    accuracy = dummy.score(feature, label)
    return accuracy

def calculateMeanRF(feature, label):
    accuracy=[]
    top4=[]
    top8=[]
    for i in range(5):
        accuracy_rf, top_accuracy_rf4, top_accuracy_rf8= rf_training (feature, label)
        accuracy.append(accuracy_rf)
        top4.append(top_accuracy_rf4)
        top8.append(top_accuracy_rf8)
    return sum(accuracy)/len(accuracy), sum(top4)/len(top4), sum(top8)/len(top8)

def calculateMeanKNN(feature, label):
    accuracy=[]
    top4=[]
    top8=[]
    for i in range(5):
        accuracy_kNN, top_accuracy_kNN4, top_accuracy_kNN8= kNN_training (feature, label)
        accuracy.append(accuracy_kNN)
        top4.append(top_accuracy_kNN4)
        top8.append(top_accuracy_kNN8)
    return sum(accuracy)/len(accuracy), sum(top4)/len(top4), sum(top8)/len(top8)

def calculateMeanAda(feature, label):
    accuracy=[]
    top4=[]
    top8=[]
    for i in range(5):
        accuracy_kNN, top_accuracy_kNN4, top_accuracy_kNN8= Ada_training (feature, label)
        accuracy.append(accuracy_kNN)
        top4.append(top_accuracy_kNN4)
        top8.append(top_accuracy_kNN8)
    return sum(accuracy)/len(accuracy), sum(top4)/len(top4), sum(top8)/len(top8)

# %% [markdown]
# # Feature Selection

# %%
#L1-based feature selection for all features
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC

linearsvc = LinearSVC(C=0.01, penalty='l1', dual=False).fit(general_allFeatures, general_label)
model = SelectFromModel(linearsvc, prefit=True)
fs_l1 = model.transform(general_allFeatures)
fs_l1.shape
# Out:
# D:\Softwares\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# (1133, 6)

# %%
# Tree-based feature selection
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
clf = ExtraTreesClassifier(n_estimators=100).fit(general_allFeatures, general_label)
model = SelectFromModel(clf, prefit=True)
fs_tree = model.transform(general_allFeatures)
fs_tree.shape
# Out:
# (1133, 7)

# %%
model.get_support([0])
# Out:
# array([0, 1, 2, 4, 5, 6, 7], dtype=int64)

# %% [markdown]
# # Model Performance

# %%
accuracy_rf, top_accuracy_rf4, top_accuracy_rf8 = calculateMeanRF(fs_tree, general_label)
print(accuracy_rf, top_accuracy_rf4, top_accuracy_rf8)
# Out:
# 0.5577464788732394 0.7535211267605634 0.8380281690140844

# %%
accuracy_kNN, top_accuracy_kNN4, top_accuracy_kNN8 = calculateMeanKNN(fs_tree, general_label)
print(accuracy_kNN, top_accuracy_kNN4, top_accuracy_kNN8)
# Out:
# 0.4190140845070422 0.6866197183098591 0.778169014084507

# %%
accuracy_ada, top_accuracy_ada4, top_accuracy_ada8 = calculateMeanAda(fs_tree, general_label)
print(accuracy_ada, top_accuracy_ada4, top_accuracy_ada8)
# Out:
# 0.3732394366197183 0.573943661971831 0.7007042253521126

# %%
accuracy_dummy = dummy_training(fs_tree, general_label)
print(accuracy_dummy)
# Out:
# 0.2409532215357458

# %% [markdown]
# # User-based vs general Model

# %%
def featureSelection(X,y):
    clf = ExtraTreesClassifier(n_estimators=100).fit(X, y)
    model = SelectFromModel(clf, prefit=True)
    fs_tree = model.transform(X)
    return fs_tree

# %%
def rf_training_USER (feature, label, testX, testy):
    valid_X = scaler.fit_transform(feature)
    valid_y = label
    X_train, X_test, y_train, y_test = valid_X, testX, valid_y, testy
    model = RandomForestClassifier(n_estimators=50).fit(X_train,y_train)
    accuracy = model.score(X_test, y_test)
    top_accuracy4 = predict_top_k(X_test, y_test, model, k=4)
    top_accuracy8 = predict_top_k(X_test, y_test, model, k=8)
    return accuracy, top_accuracy4, top_accuracy8

def calculateMeanRF_USER(feature, label, X_test, y_test):
    accuracy=[]
    top4=[]
    top8=[]
    for i in range(5):
        accuracy_rf, top_accuracy_rf4, top_accuracy_rf8= rf_training_USER (feature, label, X_test, y_test)
        accuracy.append(accuracy_rf)
        top4.append(top_accuracy_rf4)
        top8.append(top_accuracy_rf8)
    return sum(accuracy)/len(accuracy), sum(top4)/len(top4), sum(top8)/len(top8)

# %%
model.get_support([0])
# Out:
# array([0, 1, 2, 4, 5, 6, 7], dtype=int64)

# %%
allFeatures_3418_USER = allFeatures_3418[:,model.get_support([0])]
allFeatures_3418_USER.shape
# Out:
# (388, 7)

# %%
accuracy_rf_3418_USER, top_accuracy_rf_3418_USER, top_accuracy_rf8_3418_USER = calculateMeanRF_USER(general_allFeatures, general_label, allFeatures_3418, label_valid_app_3418)
print(accuracy_rf_3418_USER)
print(top_accuracy_rf_3418_USER)
print(top_accuracy_rf8_3418_USER)
# Out:
# 0.3680412371134021
# 0.7762886597938143
# 0.8525773195876288

# %% [markdown]
# # ===========================================

# %%
allFeatures_681a_USER = allFeatures_681a[:,model.get_support([0])]
allFeatures_681a_USER.shape
# Out:
# (248, 7)

# %%
accuracy_rf_681a_USER, top_accuracy_rf_681a_USER, top_accuracy_rf8_681a_USER = calculateMeanRF_USER(general_allFeatures, general_label, allFeatures_681a, label_valid_app_681a)
print(accuracy_rf_681a_USER)
print(top_accuracy_rf_681a_USER)
print(top_accuracy_rf8_681a_USER)
# Out:
# 0.2508064516129032
# 0.4717741935483872
# 0.6258064516129032

# %% [markdown]
# # Plot the figure

# %% [markdown]
# ## General Model

# %%
fd = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\general_model_r.xls")

# %%
fd.rename({"Unnamed: 0": "Evaluation"}, axis="columns", inplace=True)
#fd.rename({"App(RF)": "One Feature"},  axis="columns", inplace=True)
#fd.rename({"All31(RF)": "All 31 Features"},  axis="columns", inplace=True)
#fd.rename({"FS6(RF)": "Final 6 Features"}, axis="columns", inplace=True)
fd.rename({"Dummy": "Dummy Classifier"}, axis="columns", inplace=True)

# %%
fd
# Out:
#       Evaluation  App(kNN)  App(RF)  App(Ada)  All31(kNN)  All31(RF)  \
# 0       Accuracy    0.3908   0.4282    0.3803      0.2782     0.4261
# 1  Top4 Accuracy    0.5986   0.6458    0.5423      0.5810     0.6528
# 2  Top8 Accuracy    0.7394   0.7838    0.6796      0.7042     0.7627
#
#    All31(Ada)  FS6(kNN)  FS6(RF)  FS6(Ada)  Dummy Classifier
# 0      0.3803    0.4296   0.5915    0.3732            0.2409
# 1      0.5528    0.7113   0.7500    0.5739               NaN
# 2      0.6866    0.8275   0.8352    0.7042               NaN

# %%
fd_new = fd.drop(['App(kNN)', 'App(Ada)', 'All31(kNN)', 'All31(Ada)', 'FS6(kNN)', 'FS6(Ada)'], axis=1)
fd_new["Dummy Classifier"][1]= 0.2409
fd_new["Dummy Classifier"][2]= 0.2409
# Out:
# <ipython-input-43-af0b0e0ec0ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd_new["Dummy Classifier"][1]= 0.2409
# <ipython-input-43-af0b0e0ec0ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd_new["Dummy Classifier"][2]= 0.2409

# %%
fd_new
# Out:
#       Evaluation  App(RF)  All31(RF)  FS6(RF)  Dummy Classifier
# 0       Accuracy   0.4282     0.4261   0.5915            0.2409
# 1  Top4 Accuracy   0.6458     0.6528   0.7500            0.2409
# 2  Top8 Accuracy   0.7838     0.7627   0.8352            0.2409

# %%
ax = fd_new.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('General Performance by RandomForest', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
#ax.legend(title='Features',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


plt.savefig('General Performance.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # 3418

# %%
df3418 = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\3418_r.xls")
df3418.rename({"Unnamed: 0":"Features"}, axis="columns", inplace=True)
df3418_1 = df3418.drop(['All37(kNN)','All37(RF)','All37(Ada)','FS11(kNN)','FS11(RF)','FS11(Ada)'], axis=1)
df3418_1.rename({"App(kNN)": "kNN"}, axis='columns', inplace=True)
df3418_1.rename({"App(RF)": "RandomForest"}, axis='columns', inplace=True)
df3418_1.rename({"App(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df3418_1
# Out:
#       Evaluation     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.7320        0.7382    0.3196           0.3924
# 1  Top4 Accuracy  0.8351        0.9072    0.4639           0.3924
# 2  Top8 Accuracy  0.9278        0.9608    0.9688           0.3924

# %%
ax = df3418_1.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P3418 with one feature', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P3418 with one feature.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # ==============================================

# %%
df3418_2 = df3418.drop(['App(kNN)','App(RF)','App(Ada)','FS11(kNN)','FS11(RF)','FS11(Ada)'], axis=1)
df3418_2.rename({"All37(kNN)": "kNN"}, axis='columns', inplace=True)
df3418_2.rename({"All37(RF)": "RandomForest"}, axis='columns', inplace=True)
df3418_2.rename({"All37(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df3418_2
# Out:
#       Evaluation     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.5876        0.7340    0.7217           0.3924
# 1  Top4 Accuracy  0.8557        0.8681    0.8557           0.3924
# 2  Top8 Accuracy  0.9382        0.9258    0.9691           0.3924

# %%
ax = df3418_2.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P3418 with all 31 features', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P3418 with all 31 features.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # =====================================================\

# %%
df3418_3 = df3418.drop(['App(kNN)','App(RF)','App(Ada)','All37(kNN)','All37(RF)','All37(Ada)'], axis=1)
df3418_3.rename({"FS11(kNN)": "kNN"}, axis='columns', inplace=True)
df3418_3.rename({"FS11(RF)": "RandomForest"}, axis='columns', inplace=True)
df3418_3.rename({"FS11(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df3418_3
# Out:
#       Evaluation     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.7320        0.7422    0.7320           0.3924
# 1  Top4 Accuracy  0.8453        0.9031    0.8763           0.3924
# 2  Top8 Accuracy  0.9278        0.9629    0.9691           0.3924

# %%
ax = df3418_3.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P3418 with 6 features after fs', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P3418 with 6 features after fs.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # =========================================================

# %% [markdown]
# # 681a

# %%
df681a = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\681a_r.xls")
df681a.rename({"Unnamed: 0":"Features"}, axis="columns", inplace=True)
df681a_1 = df681a.drop(['All37(kNN)','All37(RF)','All37(Ada)','FS11(kNN)','FS11(RF)','FS11(Ada)'], axis=1)
df681a_1.rename({"App(kNN)": "kNN"}, axis='columns', inplace=True)
df681a_1.rename({"App(RF)": "RandomForest"}, axis='columns', inplace=True)
df681a_1.rename({"App(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df681a_1
# Out:
#         Features     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.3387        0.3774    0.3387           0.2782
# 1  Top4 Accuracy  0.6774        0.6434    0.5968           0.2782
# 2  Top8 Accuracy  0.7097        0.7613    0.7097           0.2782

# %%
ax = df681a_1.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P681a with one feature', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P681a with one feature.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # ==============================================

# %%
df681a_2 = df681a.drop(['App(kNN)','App(RF)','App(Ada)','FS11(kNN)','FS11(RF)','FS11(Ada)'], axis=1)
df681a_2.rename({"All37(kNN)": "kNN"}, axis='columns', inplace=True)
df681a_2.rename({"All37(RF)": "RandomForest"}, axis='columns', inplace=True)
df681a_2.rename({"All37(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df681a_2
# Out:
#         Features     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.3226        0.4291    0.3710           0.2782
# 1  Top4 Accuracy  0.5322        0.5807    0.5484           0.2782
# 2  Top8 Accuracy  0.6129        0.7032    0.6774           0.2782

# %%
ax = df681a_2.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P681a with all 31 features', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P681a with all 31 features.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # =====================================================\

# %%
df681a_3 = df681a.drop(['App(kNN)','App(RF)','App(Ada)','All37(kNN)','All37(RF)','All37(Ada)'], axis=1)
df681a_3.rename({"FS11(kNN)": "kNN"}, axis='columns', inplace=True)
df681a_3.rename({"FS11(RF)": "RandomForest"}, axis='columns', inplace=True)
df681a_3.rename({"FS11(Ada)": "AdaBoost"}, axis='columns', inplace=True)
df681a_3
# Out:
#         Features     kNN  RandomForest  AdaBoost  DummyClassifier
# 0       Accuracy  0.3065        0.4291    0.3710           0.2782
# 1  Top4 Accuracy  0.5645        0.6322    0.5645           0.2782
# 2  Top8 Accuracy  0.6290        0.7484    0.6936           0.2782

# %%
ax = df681a_3.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(10, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P681a with 6 features after fs', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P681a with 6 features after fs.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # User-based vs General Model

# %% [markdown]
# # 3418

# %%
df3418USER = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\3418_r_General.xls")
df3418USER
# Out:
#       Evaluation  RandomForest
# 0       Accuracy        0.3572
# 1  Top4 Accuracy        0.7809
# 2  Top8 Accuracy        0.8577

# %%
ax = df3418USER.plot(kind='bar', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P3418 by general model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
#ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P3418 by general model.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %%
df3418USER_MODEL = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\3418_r_General - 副本.xls")
df3418USER_MODEL
# Out:
#       Evaluation  RandomForest
# 0       Accuracy        0.7422
# 1  Top4 Accuracy        0.9031
# 2  Top8 Accuracy        0.9629

# %%
ax = df3418USER_MODEL.plot(kind='bar', color='y', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P3418 by user-based model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
#ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P3418 by user-based model.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %% [markdown]
# # 681a

# %%
df681aUSER = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\681a_r_General.xls")
df681aUSER
# Out:
#       Evaluation  RandomForest
# 0       Accuracy        0.2564
# 1  Top4 Accuracy        0.4991
# 2  Top8 Accuracy        0.6040

# %%
ax = df681aUSER.plot(kind='bar',width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P681a by general model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
#ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P681a by general model.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %%
df681aUSER_MODEL = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\681a_r_General - 副本.xls")
df681aUSER_MODEL
# Out:
#       Evaluation  RandomForest
# 0       Accuracy        0.4291
# 1  Top4 Accuracy        0.6322
# 2  Top8 Accuracy        0.7484

# %%
ax = df681aUSER_MODEL.plot(kind='bar',color='y', width=0.6, rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["Accuracy", "Top-4", "Top-8"], fontsize=14)

plt.title('P681a by user-based model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
#ax.legend(title='Models',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


#plt.savefig('P681a by user-based model.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %%
df3418ADD = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\3418_r_addition_plot.xls")
df3418ADD
# Out:
#                  Unnamed: 0  Accuracy  Top4 Accuracy  Top8 Accuracy
# 0            With 1 feature    0.7382         0.9072         0.9608
# 1      With all 31 features    0.7340         0.8681         0.9258
# 2  With 6 features after fs    0.7422         0.9031         0.9629

# %%
ax = df3418ADD.plot(kind='line', rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["1 feature", "31 features", "6 features after fs"], fontsize=14)

plt.title('P3418 by user-based model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Evaluation',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


plt.savefig('P3418 by user-based model_line.jpg',dpi=600,bbox_inches ='tight')
plt.show()

# %%
df681aADD = pd.read_excel(r"C:\Users\houxu\OneDrive\桌面\681a_r_addition_plot.xls")
df681aADD
# Out:
#                  Unnamed: 0  Accuracy  Top4 Accuracy  Top8 Accuracy
# 0            With 1 feature    0.3774         0.6434         0.7613
# 1      With all 31 features    0.4291         0.5807         0.7032
# 2  With 6 features after fs    0.4491         0.6422         0.7784

# %%
ax = df681aADD.plot(kind='line', rot=0, xlabel='..', ylabel='..',  figsize=(5, 4))



#change the xticks of the plot,
plt.xticks(range(3), ["1 feature", "31 features", "6 features after fs"], fontsize=14)

plt.title('P681a by user-based model', fontsize=20)

# add a little space at the top of the plot for the annotation
ax.margins(y=0.1)

# move the legend out of the plot
ax.legend(title='Evaluation',fontsize=10, bbox_to_anchor=(1, 1.02), loc='upper left')


plt.savefig('P681a by user-based model_line.jpg',dpi=600,bbox_inches ='tight')
plt.show()
